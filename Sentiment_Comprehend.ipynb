# %% [markdown]
# <a href="https://colab.research.google.com/github/ckmganesh/Amazon-AWS-ALEXA-Covid19-Assistant/blob/master/Sentiment_Comprehend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import boto3
import pandas as pd
import json

# %%
pip install boto3
# Out:
# ...
#      |████████████████████████████████| 133kB 6.1MB/s
# ...
#      |████████████████████████████████| 71kB 5.2MB/s
# ...
#      |████████████████████████████████| 7.3MB 7.9MB/s
# ...
#      |████████████████████████████████| 143kB 39.9MB/s
# ...
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.3 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
client_comprehend = boto3.client(
   'comprehend',
   region_name = 'ap-south-1',
   aws_access_key_id = "AKIAVKEEAHKYBDL3TTGV",
   aws_secret_access_key = "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"
)

# %%
df1=pd.read_csv("/finaldatasetindia.csv")

# %%
display(df1)
# Out:
#       Latitude  Longitude                                             Tweets
# 0            8         78  Genuinely curious as to which vaccine Modi and...
# 1            8         79  Genuinely curious as to which vaccine Modi and...
# 2            8         80  So far over 400,000 Sri Lankans vaccinated.All...
# 3            8         80   Great to hear all well with you. I guess the ...
# 4            8         80  _mathew Might be as my fitness trainer has so ...
# ...        ...        ...                                                ...
# 2118        34         75  RT : Contribution of Three neighbouring countr...
# 2119        34         75  Got vaccine queries? MyGov Corona Helpdesk got...
# 2120        34         75  IndiaFightsCorona:Do you knowCovid vaccine has...
# 2121        34         75  Mythbusters on COVID19Vaccines Myth: Vaccine n...
# 2122        34         78  Vice President, Anjuman Moin-ul Islam, Dr. Noo...
#
# [2123 rows x 3 columns]

# %%
tweets=df1['Tweets']
positive_india=[]
negative_india=[]
neutral_india=[]
mixed_india=[]
Overall_india=[]
i=0
for tweet in tweets:
  i=i+1
  sentiment = client_comprehend.detect_sentiment(LanguageCode='en',Text=tweet)
  positive_india.append(sentiment['SentimentScore']['Positive'])
  negative_india.append(sentiment['SentimentScore']['Negative'])
  neutral_india.append(sentiment['SentimentScore']['Neutral'])
  mixed_india.append(sentiment['SentimentScore']['Mixed'])
  Overall_india.append(sentiment['Sentiment'])
  print("{} tweet",i)
# Out:
# {} tweet 1
# {} tweet 2
# {} tweet 3
# {} tweet 4
# {} tweet 5
# {} tweet 6
# {} tweet 7
# {} tweet 8
# {} tweet 9
# {} tweet 10
# {} tweet 11
# {} tweet 12
# {} tweet 13
# {} tweet 14
# {} tweet 15
# {} tweet 16
# {} tweet 17
# {} tweet 18
# {} tweet 19
# {} tweet 20
# {} tweet 21
# {} tweet 22
# {} tweet 23
# {} tweet 24
# {} tweet 25
# {} tweet 26
# {} tweet 27
# {} tweet 28
# {} tweet 29
# {} tweet 30
# {} tweet 31
# {} tweet 32
# {} tweet 33
# {} tweet 34
# {} tweet 35
# {} tweet 36
# {} tweet 37
# {} tweet 38
# {} tweet 39
# {} tweet 40
# {} tweet 41
# {} tweet 42
# {} tweet 43
# {} tweet 44
# {} tweet 45
# {} tweet 46
# {} tweet 47
# {} tweet 48
# {} tweet 49
# {} tweet 50
# {} tweet 51
# {} tweet 52
# {} tweet 53
# {} tweet 54
# {} tweet 55
# {} tweet 56
# {} tweet 57
# {} tweet 58
# {} tweet 59
# {} tweet 60
# {} tweet 61
# {} tweet 62
# {} tweet 63
# {} tweet 64
# {} tweet 65
# {} tweet 66
# {} tweet 67
# {} tweet 68
# {} tweet 69
# {} tweet 70
# {} tweet 71
# {} tweet 72
# ...

# %%
df1['Positive']=positive_india
df1['Negative'] = negative_india
df1['Neutral'] = neutral_india
df1['Mixed']=mixed_india
df1['Sentiment']=Overall_india

# %%
display(df1)
# Out:
#       Latitude  Longitude  ...     Mixed  Sentiment
# 0            8         78  ...  0.001686    NEUTRAL
# 1            8         79  ...  0.001686    NEUTRAL
# 2            8         80  ...  0.000180    NEUTRAL
# 3            8         80  ...  0.050880   POSITIVE
# 4            8         80  ...  0.000137    NEUTRAL
# ...        ...        ...  ...       ...        ...
# 2118        34         75  ...  0.000288   NEGATIVE
# 2119        34         75  ...  0.000116   POSITIVE
# 2120        34         75  ...  0.000059    NEUTRAL
# 2121        34         75  ...  0.000034    NEUTRAL
# 2122        34         78  ...  0.000004    NEUTRAL
#
# [2123 rows x 8 columns]

# %%
df.to_csv('result_sentiment.csv', index=False)

# %%
grouped_multiple = df.groupby(['Latitude', 'Longitude']).agg({'Positive': 'mean'},{'Negative': 'mean'},{'Mixed': 'mean'},{'Neutral': 'mean'})
display(grouped_multiple)
# Out:
#                     Positive
# Latitude Longitude
# 25       -99        0.079605
#          -82        0.071849
#          -81        0.149278
#          -80        0.117254
#          -77        0.079947
# ...                      ...
# 49       -94        0.246843
#          -93        0.098144
#          -87        0.115866
#          -86        0.637715
#          -80        0.364220
#
# [367 rows x 1 columns]

# %%
import numpy as np

# %%
grouped=df.groupby(
   ['Latitude', 'Longitude']
).agg(
    {
         'Positive':"mean",    # Sum duration per group
         'Negative': "mean",  # get the count of networks
         'Mixed': 'mean',  # get the first date per group
          'Neutral':'mean',
          
    }
)

count_df=df.groupby(['Latitude', 'Longitude'])['Positive'].count()
grouped['Count']=count_df


conditions = [
    (grouped['Positive']>grouped['Negative'] )&(grouped['Positive']>grouped['Mixed'] )&(grouped['Positive']>grouped['Neutral'] ),
    (grouped['Neutral']>grouped['Positive'] )&(grouped['Neutral']>grouped['Mixed'] )&(grouped['Neutral']>grouped['Negative'] ),
    (grouped['Negative']>grouped['Positive'] )&(grouped['Negative']>grouped['Mixed'] )&(grouped['Negative']>grouped['Neutral'] ),
    (grouped['Mixed']>grouped['Positive'] )&(grouped['Mixed']>grouped['Negative'] )&(grouped['Mixed']>grouped['Neutral'] )
    ]
values = ['POSITIVE', 'NEUTRAL', 'NEGATIVE', 'MIXED']

grouped['Sentiment']=np.select(conditions,values)
display(grouped)
# Out:
#                     Positive  Negative     Mixed   Neutral  Count Sentiment
# Latitude Longitude
# 25       -99        0.079605  0.452195  0.116498  0.351702      2  NEGATIVE
#          -82        0.071849  0.309289  0.050560  0.568302     28   NEUTRAL
#          -81        0.149278  0.327837  0.003607  0.519277     11   NEUTRAL
#          -80        0.117254  0.468565  0.002521  0.411660      7  NEGATIVE
#          -77        0.079947  0.173219  0.018926  0.727908     82   NEUTRAL
# ...                      ...       ...       ...       ...    ...       ...
# 49       -94        0.246843  0.235608  0.004675  0.512874      6   NEUTRAL
#          -93        0.098144  0.135547  0.062233  0.704075      1   NEUTRAL
#          -87        0.115866  0.803415  0.001655  0.079065      1  NEGATIVE
#          -86        0.637715  0.003012  0.000115  0.359159      3  POSITIVE
#          -80        0.364220  0.323715  0.213755  0.098311      1  POSITIVE
#
# [367 rows x 6 columns]

# %%
grouped.to_csv("sentiment_analysis_final.csv")

# %%
# !cp sentiment_analysis_final.csv "drive/My Drive/"

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
df1.to_csv('result_sentiment_india.csv')

# %%
# !cp result_sentiment_india.csv "drive/My Drive/"

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import json

# %%
grouped=df1.groupby(
   ['Latitude', 'Longitude']
).agg(
    {
         'Positive':"mean",    # Sum duration per group
         'Negative': "mean",  # get the count of networks
         'Mixed': 'mean',  # get the first date per group
          'Neutral':'mean',
          
    }
)

count_df=df1.groupby(['Latitude', 'Longitude'])['Positive'].count()
grouped['Count']=count_df


conditions = [
    (grouped['Positive']>grouped['Negative'] )&(grouped['Positive']>grouped['Mixed'] )&(grouped['Positive']>grouped['Neutral'] ),
    (grouped['Neutral']>grouped['Positive'] )&(grouped['Neutral']>grouped['Mixed'] )&(grouped['Neutral']>grouped['Negative'] ),
    (grouped['Negative']>grouped['Positive'] )&(grouped['Negative']>grouped['Mixed'] )&(grouped['Negative']>grouped['Neutral'] ),
    (grouped['Mixed']>grouped['Positive'] )&(grouped['Mixed']>grouped['Negative'] )&(grouped['Mixed']>grouped['Neutral'] )
    ]
values = ['POSITIVE', 'NEUTRAL', 'NEGATIVE', 'MIXED']

grouped['Sentiment']=np.select(conditions,values)
display(grouped)
# Out:
#                     Positive  Negative     Mixed   Neutral  Count Sentiment
# Latitude Longitude
# 8        78         0.079176  0.207868  0.001686  0.711270      1   NEUTRAL
#          79         0.079176  0.207868  0.001686  0.711270      1   NEUTRAL
#          80         0.271410  0.187367  0.027060  0.514162     12   NEUTRAL
#          81         0.271410  0.187367  0.027060  0.514162     12   NEUTRAL
#          82         0.069212  0.150975  0.000635  0.779178      5   NEUTRAL
# ...                      ...       ...       ...       ...    ...       ...
# 34       72         0.088336  0.202651  0.017698  0.691316     23   NEUTRAL
#          73         0.107708  0.226927  0.013220  0.652144     40   NEUTRAL
#          74         0.033128  0.529145  0.254702  0.183024      3  NEGATIVE
#          75         0.065551  0.263498  0.008760  0.662191     40   NEUTRAL
#          78         0.000718  0.000227  0.000004  0.999051      1   NEUTRAL
#
# [172 rows x 6 columns]

# %%
grouped.to_csv("sentiment_analysis_final_india.csv")
# !cp sentiment_analysis_final_india.csv "drive/My Drive/"
